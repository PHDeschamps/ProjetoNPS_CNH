    9, 8, 8, 8, 8, 8, 6, 5, 8, 8, 8, 7, 7, 9, 7, 8, 8, 8, 8, 8, 6, 7, 9, 7, 10, 9, 8, 10, 8, 8, 6, 9, 10, 8,
    7, 8, 9, 9, 9, 8, 8, 8, 8, 9, 7, 10, 5, 8, 10, 10, 8, 7, 8, 8, 8, 10, 8, 8, 8, 8, 10, 8, 9, 9, 7, 6, 8, 8,
    7, 8, 9, 9, 7, 8, 8, 9, 8, 8, 5, 9, 10, 10, 10, 9, 8, 8, 6, 8, 7, 8, 7, 8, 3, 8, 8, 9, 8, 7, 8, 8, 10, 8,
    8, 8, 8, 10, 8, 8, 10, 9, 8, 8, 8, 8, 10, 9, 8, 7, 6, 8, 8, 8, 8, 8, 8, 9, 8, 9, 8, 10, 8, 9, 10, 7, 9, 7,
    8, 7, 9, 9, 8, 8, 10, 8, 9, 9, 9, 7, 8, 9, 8, 8, 9, 6, 9, 8, 8, 8, 10, 8, 9, 8, 9, 7, 10, 9, 8, 8, 6, 9,
    10, 7, 8, 7, 9, 8, 10, 8, 8, 9, 6, 8, 7, 8, 9, 8, 9, 10, 9, 10, 5, 8, 10, 10, 10, 9, 9, 8, 8, 10, 10, 8,
    10, 9, 7, 9, 9, 10, 9, 10, 8, 8, 9, 8, 7, 8, 9, 8, 9, 8, 8, 10, 7, 10, 7, 10, 8, 10, 10, 8, 8, 8, 8, 8,
    6, 8, 7, 7, 8, 7, 7, 8, 8, 7, 7, 8, 7, 10, 8, 8, 10, 7, 10, 8, 10, 9
]
geracao_transmissao_dados_frota = [
    8, 7, 9, 8, 6, 6, 9, 7, 8, 3, 8, 7, 10, 0, 4,
    5, 8, 7, 8, 0, 6, 9, 10, 5, 0, 0, 9, 6, 8, 7, 0,
    5, 8, 7, 8, 8, 1, 5, 6, 0, 10, 8, 10, 7, 1, 10, 0,
    8, 9, 8, 6, 3, 8, 10, 8, 10, 0, 0, 10, 8, 8, 7, 9,
    8, 9, 6, 10, 0, 5, 7, 0, 2, 8, 8, 8, 8, 5, 8, 8,
    8, 4, 7, 7, 8, 8, 9, 7, 5, 8, 0, 10, 8, 8, 8, 9,
    9, 10, 7, 5, 0, 9, 5, 9, 7, 8, 9, 10, 0, 8, 8, 0,
    0, 7, 7, 9, 9, 9, 10, 9, 9, 8, 6, 8, 8, 7, 8, 7,
    7, 8, 10, 10, 8, 10
]

def plot_performance_metrics():
    # Metrics calculated from original data
    metrics = [
        'Facilidade de Operação',
        'Conforto e Ergonomia',
        'Capacidade Operacional',
        'Disponibilidade/Confiabilidade',
        'Custo de Manutenção',
        'Facilidade Manutenções',
        'Consumo Combustível',
        'Adequação Implementos',
        'Piloto Automático',
        'Dados Gestão Agrícola',
        'Adaptabilidade Trabalho',
        'Dados Gestão Frota'
    ]

    values = [
        calcular_media(facilidade_operacao), calcular_media(conforto_ergonomia),
        calcular_media(capacidade_operacional), calcular_media(disponibilidade_confiabilidade),
        calcular_media(custo_manutencao), calcular_media(facilidade_manutencoes),
        calcular_media(consumo_combustivel), calcular_media(adequacao_implementos),
        calcular_media(facilidade_piloto_automatico), calcular_media(geracao_transmissao_dados_agricola),
        calcular_media(adaptabilidade_trabalho), calcular_media(geracao_transmissao_dados_frota)
    ]

    plt.figure(figsize=(10, 6))
    plt.barh(metrics, values, color='blue', alpha=0.7)
    plt.xlabel('Pontuação (0-10)')
    plt.title('Media de Neutros')
    plt.xlim(0, 10)
    plt.tight_layout()
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    for i, v in enumerate(values):
        plt.text(v + 0.1, i, str(v), va='center')

    plt.show()

plot_performance_metrics()

print(f"A média de facilidade de operação(csat) é: {calcular_media(facilidade_operacao)}")
print(f"A média de conforto e ergonomia (csat) é: {calcular_media(conforto_ergonomia)}")
print(f"A média de capacidade operacional (hectares por hora) (csat) é: {calcular_media(capacidade_operacional)}")
print(f"A média de disponibilidade e confiabilidade mecânica  (csat) é: {calcular_media(disponibilidade_confiabilidade)}")
print(f"A média de custo de manutenção (csat) é: {calcular_media(custo_manutencao)}")
print(f"A média de facilidade para realização de manutenções (csat) é: {calcular_media(facilidade_manutencoes)}")
print(f"A média de consumo de combustível (litros por hectares) (csat) é: {calcular_media(consumo_combustivel)}")
print(f"A média de adequação as diversas operações e implementos (csat) é: {calcular_media(adequacao_implementos)}")
print(f"A média de facilidade de uso do piloto automático (csat) é: {calcular_media(facilidade_piloto_automatico)}")
print(f"A média de geração e transmissão de dados para gestão agrícola (csat) é: {calcular_media(geracao_transmissao_dados_agricola)}")
print(f"A média de adaptabilidade as mais diversas condições de trabalho (csat) é: {calcular_media(adaptabilidade_trabalho)}")
print(f"A média de geração e transmissão de dados para gestão da frota (csat) é: {calcular_media(geracao_transmissao_dados_frota)}")
# Out:
# A média de facilidade de operação(csat) é: 8
# A média de conforto e ergonomia (csat) é: 7
# A média de capacidade operacional (hectares por hora) (csat) é: 8
# A média de disponibilidade e confiabilidade mecânica  (csat) é: 8
# A média de custo de manutenção (csat) é: 7
# A média de facilidade para realização de manutenções (csat) é: 8
# A média de consumo de combustível (litros por hectares) (csat) é: 8
# A média de adequação as diversas operações e implementos (csat) é: 8
# A média de facilidade de uso do piloto automático (csat) é: 6
# A média de geração e transmissão de dados para gestão agrícola (csat) é: 7
# A média de adaptabilidade as mais diversas condições de trabalho (csat) é: 8
# A média de geração e transmissão de dados para gestão da frota (csat) é: 7

# %% [markdown]
# Media dos Detratores

# %%
import matplotlib.pyplot as plt

def calcular_media(numeros):
    if len(numeros) == 0:
        return 0
    return round(sum(numeros) / len(numeros))

capacidade_operacional = [
2, 7, 5, 7, 6, 7, 6, 6, 0, 2, 8, 2, 5, 7, 0, 5, 1, 10, 5, 0, 2, 8, 2, 6, 5, 8, 3, 3, 1, 3, 5, 2, 5, 5, 9, 7, 5, 2, 2, 6, 7, 0, 1, 3,
4, 9, 7, 3, 5, 1, 6, 7, 10, 0, 0, 1, 5, 6, 9, 5, 7, 5, 5, 8, 5, 7, 7, 7, 2, 4, 4, 4, 1, 5, 6, 7, 4, 3, 8, 0, 7, 0, 1, 6, 2, 8, 8, 7,
    3, 2, 4, 6, 2, 1, 0, 7, 0, 4, 6, 8, 5, 0, 1, 0, 0, 9, 9, 5, 0, 7, 7, 0, 7, 1, 0, 7, 8, 6, 0, 0, 8, 5, 0, 8, 7, 5, 2, 0,
    0, 7, 5, 5, 4, 0, 4, 8, 0, 8, 6, 6, 1, 7, 8, 9, 0, 7, 8, 6, 6, 5, 3, 3, 7, 8, 0, 7, 3, 6, 6, 6, 4, 6, 0, 8, 7, 7, 7, 8, 7, 7, 7
]

custo_manutencao = [
    5, 1, 3, 2, 0, 0, 6, 0, 3, 6, 9, 5, 1, 1, 0, 0, 0, 9, 5, 0, 3, 6, 0, 5, 0, 0, 5, 7, 6, 0, 0, 6, 9, 5, 5, 4, 7, 4, 0,
    0, 7, 7, 6, 1, 7, 5, 6, 0, 9, 7, 6, 2, 7, 7, 8, 1, 8, 7, 6, 0, 9, 3, 9, 9, 3, 4, 5, 7, 4, 7, 6, 0, 6, 3, 4, 6, 9, 8, 6, 8, 6, 6
]

consumo_combustivel = [
    8, 5, 5, 4, 6, 6, 6, 0, 3, 8, 9, 4, 10, 8, 8, 0, 5, 7, 9, 5, 0, 8, 7, 3, 8, 7, 3, 5, 9, 5, 0, 9, 2, 6, 4, 3, 6, 5, 7, 4,
    10, 4, 8, 6, 4, 9, 4, 10, 2, 8, 8, 6, 4, 7, 6, 8, 9, 8, 8, 5, 0, 9, 9, 8, 7, 8, 6, 8, 8, 6, 9, 7, 6, 8, 8, 7, 7, 8, 7, 10, 8, 9
]

adaptabilidade_trabalho = [
    9, 7, 4, 10, 7, 5, 6, 7, 0, 4, 6, 4, 3, 7, 7, 7, 0, 2, 6, 9, 5, 0, 6, 7, 3, 7, 3, 6, 5, 0, 9, 3, 3, 5, 4, 6, 6, 6, 5,
    10, 7, 7, 7, 7, 7, 5, 8, 6, 9, 8, 6, 4, 8, 8, 8, 7, 9, 8, 5, 0, 8, 9, 8, 8, 9, 6, 7, 7, 6, 7, 7, 8, 7, 7, 7, 7, 7, 9, 7, 7, 7, 9
]

facilidade_piloto_automatico = [
    0, 0, 0, 0, 0, 1, 5, 0, 1, 0, 0, 0, 0, 0, 10, 0, 0, 0, 0, 0, 5, 0, 4, 3,
    0, 0, 0, 1, 0, 0, 6, 0, 1, 5, 0, 1, 10, 0, 0, 6, 3, 1, 6, 7, 10, 0, 8, 6, 0, 5, 1,
    1, 6, 3, 0, 6, 0, 10, 7, 5, 6, 0, 1, 0
]

geracao_transmissao_dados_frota = [
    0, 6, 0, 0, 3, 5, 9, 3, 0, 0, 0, 0, 5, 9, 0, 0, 5, 6, 0, 0, 5, 5,
    4, 0, 0, 3, 4, 9, 3, 0, 5, 0, 6, 3, 3, 9, 9, 7, 10, 8, 6, 6, 9, 9,
    0, 8, 10, 9, 8, 8, 8, 7, 6, 9, 6, 9, 5, 7, 10, 8, 10, 5, 9, 5
]

geracao_transmissao_dados_agricola = [
    0, 5, 0, 0, 2, 9, 3, 0, 0, 0, 0, 5, 9, 0, 0, 5, 6, 1,
    7, 5, 6, 7, 1, 1, 9, 9, 6, 5, 3, 10,
    8, 10, 8, 6, 6, 9, 9, 7, 10, 9, 9, 10, 9, 8, 9, 6, 7, 9,  10, 6, 5, 10, 8
]

def plot_performance_metrics():
    # Metrics calculated from original data
    metrics = [
        'Facilidade de Operação',
        'Conforto e Ergonomia',
        'Capacidade Operacional',
        'Disponibilidade/Confiabilidade',
        'Custo de Manutenção',
        'Facilidade Manutenções',
        'Consumo Combustível',
        'Adequação Implementos',
        'Piloto Automático',
        'Dados Gestão Agrícola',
        'Adaptabilidade Trabalho',
        'Dados Gestão Frota'
    ]

    values = [
        calcular_media(facilidade_operacao), calcular_media(conforto_ergonomia),
        calcular_media(capacidade_operacional), calcular_media(disponibilidade_confiabilidade),
        calcular_media(custo_manutencao), calcular_media(facilidade_manutencoes),
        calcular_media(consumo_combustivel), calcular_media(adequacao_implementos),
        calcular_media(facilidade_piloto_automatico), calcular_media(geracao_transmissao_dados_agricola),
        calcular_media(adaptabilidade_trabalho), calcular_media(geracao_transmissao_dados_frota)
    ]

    plt.figure(figsize=(10, 6))
    plt.barh(metrics, values, color='blue', alpha=0.7)
    plt.xlabel('Pontuação (0-10)')
    plt.title('Media de Detratores')
    plt.xlim(0, 10)
    plt.tight_layout()
    plt.grid(axis='x', linestyle='--', alpha=0.7)

    for i, v in enumerate(values):
        plt.text(v + 0.1, i, str(v), va='center')

    plt.show()

plot_performance_metrics()

print(f"A média de facilidade de operação(csat) é: {calcular_media(facilidade_operacao)}")
print(f"A média de conforto e ergonomia (csat) é: {calcular_media(conforto_ergonomia)}")
print(f"A média de capacidade operacional (hectares por hora) (csat) é: {calcular_media(capacidade_operacional)}")
print(f"A média de disponibilidade e confiabilidade mecânica  (csat) é: {calcular_media(disponibilidade_confiabilidade)}")
print(f"A média de custo de manutenção (csat) é: {calcular_media(custo_manutencao)}")
print(f"A média de facilidade para realização de manutenções (csat) é: {calcular_media(facilidade_manutencoes)}")
print(f"A média de consumo de combustível (litros por hectares) (csat) é: {calcular_media(consumo_combustivel)}")
print(f"A média de adequação as diversas operações e implementos (csat) é: {calcular_media(adequacao_implementos)}")
print(f"A média de facilidade de uso do piloto automático (csat) é: {calcular_media(facilidade_piloto_automatico)}")
print(f"A média de geração e transmissão de dados para gestão agrícola (csat) é: {calcular_media(geracao_transmissao_dados_agricola)}")
print(f"A média de adaptabilidade as mais diversas condições de trabalho (csat) é: {calcular_media(adaptabilidade_trabalho)}")
print(f"A média de geração e transmissão de dados para gestão da frota (csat) é: {calcular_media(geracao_transmissao_dados_frota)}")
# Out:
# A média de facilidade de operação(csat) é: 6
# A média de conforto e ergonomia (csat) é: 6
# A média de capacidade operacional (hectares por hora) (csat) é: 5
# A média de disponibilidade e confiabilidade mecânica  (csat) é: 4
# A média de custo de manutenção (csat) é: 4
# A média de facilidade para realização de manutenções (csat) é: 5
# A média de consumo de combustível (litros por hectares) (csat) é: 6
# A média de adequação as diversas operações e implementos (csat) é: 5
# A média de facilidade de uso do piloto automático (csat) é: 2
# A média de geração e transmissão de dados para gestão agrícola (csat) é: 6
# A média de adaptabilidade as mais diversas condições de trabalho (csat) é: 6
# A média de geração e transmissão de dados para gestão da frota (csat) é: 5
